# %% [markdown]
# # Tugas Eksperimen 1 DAA 2023/2025
# **Nama      : Divany Harryndira**
# **NPM       : 2106701735**
# **Kode Asdos: 1**

# %% [markdown]
# ## Persiapan Pra Eksperimen

# %% [markdown]
# ### Import Library

# %%
import math
import time
import tracemalloc

# %% [markdown]
# ### Mendefinisikan Function Pendukung BCIS

# %%
# Function ini untuk swap elemen pada array.
def swap(array, i, j):
    temp = array[i]
    array[i] = array[j]
    array[j] = temp

# Function ini untuk memastikan bahwa pivot sl dan sr tidak sama.
# Jika sama, function ini juga memeriksa apakah kedua pivot memang
# bernilai sama atau sebenarnya adalah elemen yang sama.
def is_equal(array, sl, sr):
    for k in range(sl+1, sr):
        if array[k] != array[sl]:
            swap(array, k, sl)
            return k
    return -1

# Function ini untuk memasukkan current element ke subarray kanan
def insert_right(array, curr, sr, right):
    j = sr
    while (j <= right):
        if (curr > array[j]):
            array[j-1] = array[j]
            j = j+1
        else:break
    array[j-1] = curr

# Function ini untuk memasukkan current element ke subarray kiri
def insert_left(array, curr, sl, left):
    j = sl
    while (j >= left):
        if (curr < array[j]):
            array[j+1] = array[j]
            j = j-1
        else:
            break
    array[j+1] = curr

# %% [markdown]
# ### Function BCIS

# %%
def bcis(array, left, right):
    sl = left
    sr = right
    while sl < sr:
        swap(array, sr, sl + int((sr-sl)/2))
        if array[sl] == array[sr]:
            if is_equal(array, sl, sr) == -1:
                return
        if array[sl] > array[sr] :
            swap(array, sl, sr)
        if (sr-sl) >= 100:
            for i in range(sl+1, int(math.sqrt(sr-sl))):
                if array[sr] < array[i]:
                    swap(array, sr, i)
                elif array[sl] > array[i]:
                    swap(array, sl, i)
        else:
            i = sl+1

        lc = array[sl]
        rc = array[sr]
        while i < sr:
            # print(array)
            curr = array[i]
            # print(curr)
            if curr >= rc:
                array[i] = array[sr-1]
                insert_right(array, curr, sr, right)
                sr = sr-1
            elif curr <= lc:
                array[i] = array[sl+1]
                insert_left(array, curr, sl, left)
                sl = sl+1
                i = i+1
            else:
                i = i+1
        sl = sl+1
        sr = sr-1

# %% [markdown]
# ### Function Counting Sort

# %%
# Referensi: https://www.programiz.com/dsa/counting-sort

def countingSort(array):
    size = len(array)
    output = [0] * size

    # Initialize count array
    count = [0] * size

    # Store the count of each elements in count array
    for i in range(0, size):
        count[array[i]] += 1

    # Store the cummulative count
    for i in range(1, size):
        count[i] += count[i - 1]

    # Find the index of each element of the original array in count array
    # place the elements in output array
    i = size - 1
    while i >= 0:
        output[count[array[i]] - 1] = array[i]
        count[array[i]] -= 1
        i -= 1

    # Copy the sorted elements into original array
    for i in range(0, size):
        array[i] = output[i]

# %% [markdown]
# ### Memasukkan Dataset

# %%
dataset_random500 = []
dataset_random5000 = []
dataset_random50000 = []
dataset_reversed500 = []
dataset_reversed5000 = []
dataset_reversed50000 = []
dataset_sorted500 = []
dataset_sorted5000 = []
dataset_sorted50000 = []

with open('./data/random_500.txt', 'r') as file:
    all_file = file.read().strip()  # Read and remove any extra new line
    all_file_list = all_file.split('\n')  # make a list of lines
    for num in all_file_list:
        dataset_random500.append(int(num))

with open('./data/random_5000.txt', 'r') as file:
    all_file = file.read().strip()  # Read and remove any extra new line
    all_file_list = all_file.split('\n')  # make a list of lines
    for num in all_file_list:
        dataset_random5000.append(int(num))

with open('./data/random_50000.txt', 'r') as file:
    all_file = file.read().strip()  # Read and remove any extra new line
    all_file_list = all_file.split('\n')  # make a list of lines
    for num in all_file_list:
        dataset_random50000.append(int(num))

with open('./data/reversed_500.txt', 'r') as file:
    all_file = file.read().strip()  # Read and remove any extra new line
    all_file_list = all_file.split('\n')  # make a list of lines
    for num in all_file_list:
        dataset_reversed500.append(int(num))

with open('./data/reversed_5000.txt', 'r') as file:
    all_file = file.read().strip()  # Read and remove any extra new line
    all_file_list = all_file.split('\n')  # make a list of lines
    for num in all_file_list:
        dataset_reversed5000.append(int(num))

with open('./data/reversed_50000.txt', 'r') as file:
    all_file = file.read().strip()  # Read and remove any extra new line
    all_file_list = all_file.split('\n')  # make a list of lines
    for num in all_file_list:
        dataset_reversed50000.append(int(num))

with open('./data/sorted_500.txt', 'r') as file:
    all_file = file.read().strip()  # Read and remove any extra new line
    all_file_list = all_file.split('\n')  # make a list of lines
    for num in all_file_list:
        dataset_sorted500.append(int(num))

with open('./data/sorted_5000.txt', 'r') as file:
    all_file = file.read().strip()  # Read and remove any extra new line
    all_file_list = all_file.split('\n')  # make a list of lines
    for num in all_file_list:
        dataset_sorted5000.append(int(num))

with open('./data/sorted_50000.txt', 'r') as file:
    all_file = file.read().strip()  # Read and remove any extra new line
    all_file_list = all_file.split('\n')  # make a list of lines
    for num in all_file_list:
        dataset_sorted50000.append(int(num))

# %% [markdown]
# ### Function untuk menghitung alokasi memori

# %%
def sum_memory(snapshot):
    snapshot = snapshot.filter_traces((
        tracemalloc.Filter(False, "<frozen importlib._bootstrap>"),
        tracemalloc.Filter(False, "<unknown>"),
    ))
    top_stats = snapshot.statistics('lineno')
    total = sum(stat.size for stat in top_stats)
    print("Total allocated size: %.1f KiB" % (total / 1024))

def memory_diff(snapshot1, snapshot2):
    snapshot2 = snapshot2.filter_traces((
        tracemalloc.Filter(False, "<frozen importlib._bootstrap>"),
        tracemalloc.Filter(False, "<unknown>"),
    ))
    top_stats = snapshot2.compare_to(snapshot1, 'lineno')
    total = sum(stat.size for stat in top_stats)
    print("Total allocated size: %.1f KiB" % (total / 1024))

# %% [markdown]
# ## Melakukan Eksperimen

# %% [markdown]
# ### Dataset Random 500 Angka

# %%
tracemalloc.start()
start = time.time()
data = dataset_random500.copy()
bcis(data, 0, len(data)-1)
end = time.time()
snapshot = tracemalloc.take_snapshot()
print("Sorted Array in Ascending Order: ")
print(data)
print("The time of execution of above program is :",
      (end-start) * 10**3, "ms")
sum_memory(snapshot)
# Out:
# Sorted Array in Ascending Order:
# ...

# %%
start2 = time.time()
data2 = dataset_random500.copy()
countingSort(data2)
snapshot2 = tracemalloc.take_snapshot()
end2 = time.time()
print("Sorted Array in Ascending Order: ")
print(data2)
print("The time of execution of above program is :",
      (end2-start2) * 10**3, "ms")
memory_diff(snapshot, snapshot2)
# Out:
# Sorted Array in Ascending Order:
# ...

# %% [markdown]
# ### Dataset Random 5000 Angka

# %%
start3 = time.time()
data3 = dataset_random5000.copy()
bcis(data3, 0, len(data3)-1)
end3 = time.time()
snapshot3 = tracemalloc.take_snapshot()
print("Sorted Array in Ascending Order: ")
print(data3)
print("The time of execution of above program is :",
      (end3-start3) * 10**3, "ms")
memory_diff(snapshot2, snapshot3)
# Out:
# Sorted Array in Ascending Order:
# ...

# %%
start4 = time.time()
data4 = dataset_random5000.copy()
countingSort(data4)
snapshot4 = tracemalloc.take_snapshot()
end4 = time.time()
print("Sorted Array in Ascending Order: ")
print(data4)
print("The time of execution of above program is :",
      (end4-start4) * 10**3, "ms")
memory_diff(snapshot3, snapshot4)
# Out:
# Sorted Array in Ascending Order:
# ...

# %% [markdown]
# ### Dataset Random 50000 Angka

# %%
start5 = time.time()
data5 = dataset_random50000.copy()
bcis(data5, 0, len(data5)-1)
end5 = time.time()
snapshot5 = tracemalloc.take_snapshot()
print("Sorted Array in Ascending Order: ")
print(data5)
print("The time of execution of above program is :",
      (end5-start5) * 10**3, "ms")
memory_diff(snapshot4, snapshot5)
# Out:
# Sorted Array in Ascending Order:
# ...

# %%
start6 = time.time()
data6 = dataset_random50000.copy()
countingSort(data6)
snapshot6 = tracemalloc.take_snapshot()
end6 = time.time()
print("Sorted Array in Ascending Order: ")
print(data6)
print("The time of execution of above program is :",
      (end6-start6) * 10**3, "ms")
memory_diff(snapshot5, snapshot6)
# Out:
# Sorted Array in Ascending Order:
# ...

# %% [markdown]
# ### Dataset Reversed 500 Angka

# %%
start7 = time.time()
data7 = dataset_reversed500.copy()
bcis(data7, 0, len(data7)-1)
end7 = time.time()
snapshot7 = tracemalloc.take_snapshot()
print("Sorted Array in Ascending Order: ")
print(data7)
print("The time of execution of above program is :",
      (end7-start7) * 10**3, "ms")
memory_diff(snapshot6, snapshot7)
# Out:
# Sorted Array in Ascending Order:
# ...

# %%
start8 = time.time()
data8 = dataset_reversed500.copy()
countingSort(data8)
snapshot8 = tracemalloc.take_snapshot()
end8 = time.time()
print("Sorted Array in Ascending Order: ")
print(data8)
print("The time of execution of above program is :",
      (end8-start8) * 10**3, "ms")
memory_diff(snapshot7, snapshot8)
# Out:
# Sorted Array in Ascending Order:
# ...

# %% [markdown]
# ### Dataset Reversed 5000 Angka

# %%
start9 = time.time()
data9 = dataset_reversed5000.copy()
bcis(data9, 0, len(data9)-1)
end9 = time.time()
snapshot9 = tracemalloc.take_snapshot()
print("Sorted Array in Ascending Order: ")
print(data9)
print("The time of execution of above program is :",
      (end9-start9) * 10**3, "ms")
memory_diff(snapshot8, snapshot9)
# Out:
# Sorted Array in Ascending Order:
# ...

# %%
start10 = time.time()
data10 = dataset_reversed5000.copy()
countingSort(data10)
snapshot10 = tracemalloc.take_snapshot()
end10 = time.time()
print("Sorted Array in Ascending Order: ")
print(data10)
print("The time of execution of above program is :",
      (end10-start10) * 10**3, "ms")
memory_diff(snapshot9, snapshot10)
# Out:
# Sorted Array in Ascending Order:
# ...

# %% [markdown]
# ### Dataset Reversed 50000 Angka

# %%
start11 = time.time()
data11 = dataset_reversed50000.copy()
bcis(data11, 0, len(data11)-1)
end11 = time.time()
snapshot11 = tracemalloc.take_snapshot()
print("Sorted Array in Ascending Order: ")
print(data11)
print("The time of execution of above program is :",
      (end11-start11) * 10**3, "ms")
memory_diff(snapshot10, snapshot11)
# Out:
# Sorted Array in Ascending Order:
# ...

# %%
start12 = time.time()
data12 = dataset_reversed50000.copy()
countingSort(data12)
snapshot12 = tracemalloc.take_snapshot()
end12 = time.time()
print("Sorted Array in Ascending Order: ")
print(data12)
print("The time of execution of above program is :",
      (end12-start12) * 10**3, "ms")
memory_diff(snapshot11, snapshot12)
# Out:
# Sorted Array in Ascending Order:
# ...

# %% [markdown]
# ### Dataset Sorted 500 Angka

# %%
start13 = time.time()
data13 = dataset_sorted500.copy()
bcis(data13, 0, len(data13)-1)
end13 = time.time()
snapshot13 = tracemalloc.take_snapshot()
print("Sorted Array in Ascending Order: ")
print(data13)
print("The time of execution of above program is :",
      (end13-start13) * 10**3, "ms")
memory_diff(snapshot12, snapshot13)
# Out:
# Sorted Array in Ascending Order:
# ...

# %%
start14 = time.time()
data14 = dataset_sorted500.copy()
countingSort(data14)
snapshot14 = tracemalloc.take_snapshot()
end14 = time.time()
print("Sorted Array in Ascending Order: ")
print(data14)
print("The time of execution of above program is :",
      (end14-start14) * 10**3, "ms")
memory_diff(snapshot13, snapshot14)
# Out:
# Sorted Array in Ascending Order:
# ...

# %% [markdown]
# ### Dataset Sorted 5000 Angka

# %%
start15 = time.time()
data15 = dataset_sorted5000.copy()
bcis(data15, 0, len(data15)-1)
end15 = time.time()
snapshot15 = tracemalloc.take_snapshot()
print("Sorted Array in Ascending Order: ")
print(data15)
print("The time of execution of above program is :",
      (end15-start15) * 10**3, "ms")
memory_diff(snapshot14, snapshot15)
# Out:
# Sorted Array in Ascending Order:
# ...

# %%
start16 = time.time()
data16 = dataset_sorted5000.copy()
countingSort(data16)
snapshot16 = tracemalloc.take_snapshot()
end16 = time.time()
print("Sorted Array in Ascending Order: ")
print(data16)
print("The time of execution of above program is :",
      (end16-start16) * 10**3, "ms")
memory_diff(snapshot15, snapshot16)
# Out:
# Sorted Array in Ascending Order:
# ...

# %% [markdown]
# ### Dataset Sorted 50000 Angka

# %%
start17 = time.time()
data17 = dataset_sorted50000.copy()
bcis(data17, 0, len(data17)-1)
end17 = time.time()
snapshot17 = tracemalloc.take_snapshot()
print("Sorted Array in Ascending Order: ")
print(data17)
print("The time of execution of above program is :",
      (end17-start17) * 10**3, "ms")
memory_diff(snapshot16, snapshot17)
# Out:
# Sorted Array in Ascending Order:
# ...

# %%
start18 = time.time()
data18 = dataset_sorted50000.copy()
countingSort(data18)
snapshot18 = tracemalloc.take_snapshot()
end18 = time.time()
print("Sorted Array in Ascending Order: ")
print(data18)
print("The time of execution of above program is :",
      (end18-start18) * 10**3, "ms")
memory_diff(snapshot17, snapshot18)
# Out:
# Sorted Array in Ascending Order:
# ...
